# %%
import random

jpNum=   {1:'新宿車站附近百貨公司',2:'明治神宮',3:'表參道',4:'SHIBUYA109',
          5:'淺草寺',6:'上野公園',7:'築地市場',8:'台場公園',9:'吉祥寺商店街', 
          10:'下北澤一番街',11:'東京鐵塔',12:'晴空塔',13:'東京迪士尼'
         }

jpWeight={'新宿車站附近百貨公司':12,'明治神宮':3,'表參道':6,'SHIBUYA109':3,
          '淺草寺':3,'上野公園':3,'築地市場':4,'台場公園':5,'吉祥寺商店街':3, 
          '下北澤一番街':3,'東京鐵塔':2,'晴空塔':4,'東京迪士尼':12
         }

jpInfo={'新宿車站附近百貨公司':'分為東新宿與西新宿區域，整個新宿本身就是各大百貨公司戰區，光0101就有三間、Lumine兩間、伊勢丹兩間，更別說那些知名品牌店在此就有幾間分店，常常有一種怎麼走都在原地打轉的感覺，明明剛剛才來過這間百貨公司或這間店啊?其實是從這間分店走到另外一間分店而已。',
        '明治神宮':'是供奉明治天皇（於1912年過世）和昭憲皇太后（於1914年過世）靈位的地方為日本神道的重要神社~~',
        '表參道':'表參道與明治通的交差點，即神宮前交差點以東，為日本著名外國品牌時裝店林立之地。',
        'SHIBUYA109':'日本東急電鐵的全資子公司「株式會社SHIBUYA109娛樂」所開設的時裝大樓及企業品牌。「109」的名稱來自「東急」的日語諧音。',
        '淺草寺':'有著名的「淺草雷門」，古色古香的商店街',
        '上野公園':'最熱鬧，最有名，歷史最悠久的東京賞櫻地點。',
        '築地市場':'有最新鮮的生魚片海鮮等等，場內場外每個大街小巷裡，都可以看得到日本道地的風情',
        '台場公園':'填海造陸的巨大人工島，可以看到美麗的東京灣、彩虹大橋，還可遠眺東京鐵塔',
        '吉祥寺商店街':'新宿以西最大的商業區，百貨公司、郵局、餐廳、個性小店排排站', 
        '下北澤一番街':'大量有濃厚日本風格的古著、雜貨店，還有許多小型劇場',
        '東京鐵塔':'東京鐵塔在150米處設有大瞭望台，249.9米處設有特別瞭望台，可一覽東京都內景色，晴朗之日可遠眺富士山。還有水族館',
        '晴空塔':'東京新地標，有商場',
        '東京迪士尼':'迪士尼，很多東西很好玩，但人非常多'
       }

day =int(input('請輸入你想要去幾天（建議5,6天）：'))
count=0
schedule=[]
aa=[]
while (count<day*12):
    a=random.randint(1,len(jpNum))
    if a in aa:
        a=random.randint(1,len(jpNum))
    else:
        aa.append(a)
        count=count+jpWeight.get(jpNum.get(a))
        schedule.append(jpNum.get(a))
#print(aa)
print('這',day,'天，給您的建議行程為：')

for i in schedule:
    print(i,':',jpInfo.get(i))
# Out:
# 請輸入你想要去幾天（建議5,6天）：3
# 這 3 天，給您的建議行程為：
# 晴空塔 : 東京新地標，有商場
# 東京鐵塔 : 東京鐵塔在150米處設有大瞭望台，249.9米處設有特別瞭望台，可一覽東京都內景色，晴朗之日可遠眺富士山。還有水族館
# 明治神宮 : 是供奉明治天皇（於1912年過世）和昭憲皇太后（於1914年過世）靈位的地方為日本神道的重要神社~~
# 台場公園 : 填海造陸的巨大人工島，可以看到美麗的東京灣、彩虹大橋，還可遠眺東京鐵塔
# 吉祥寺商店街 : 新宿以西最大的商業區，百貨公司、郵局、餐廳、個性小店排排站
# 新宿車站附近百貨公司 : 分為東新宿與西新宿區域，整個新宿本身就是各大百貨公司戰區，光0101就有三間、Lumine兩間、伊勢丹兩間，更別說那些知名品牌店在此就有幾間分店，常常有一種怎麼走都在原地打轉的感覺，明明剛剛才來過這間百貨公司或這間店啊?其實是從這間分店走到另外一間分店而已。
# 表參道 : 表參道與明治通的交差點，即神宮前交差點以東，為日本著名外國品牌時裝店林立之地。
# 上野公園 : 最熱鬧，最有名，歷史最悠久的東京賞櫻地點。
